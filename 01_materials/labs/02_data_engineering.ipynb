# %%
# %load_ext dotenv
# %dotenv

# %% [markdown]
# # What are we doing?
#
# ## Objectives
#
#
# * Build a data pipeline that downloads price data from the internet, stores it locally, transforms it into return data, and stores the feature set.
#     - Getting the data.
#     - Schemas and index in dask.
#
# * Explore the parquet format.
#     - Reading and writing parquet files.
#     - Read datasets that are stored in distributed files.
#     - Discuss dask vs pandas as a small example of big vs small data.
#
# * Discuss the use of environment variables for settings.
# * Discuss how to use Jupyter notebooks and source code concurrently.
# * Logging and using a standard logger.
#
# ## About the Data
#
# + We will download the prices for a list of stocks.
# + The source is Yahoo Finance and we will use the API provided by the library yfinance.
#
#
# ## Medallion Architecture
#
# + The architecture that we are thinking about is called Medallion by [DataBricks](https://www.databricks.com/glossary/medallion-architecture). It is an ELT type of thinking, although our data is well-structured.
#
# ![Medallion Architecture (DataBicks)](./images/02_medallion_architecture.png)
#
# + In our case, we would like to optimize the number of times that we download data from the internet.
# + Ultimately, we will build a pipeline manager class that will help us control the process of obtaining and transforming our data.
#
# ![](./images/02_target_pipeline_manager.png)

# %% [markdown]
# # Download Data from Yahoo Finance
#
# Yahoo Finance provides information about public stocks in different markets. The library yfinance gives us access to a fair bit of the data in Yahoo Finance.
#
# These steps are based on the instructions in:
#
# + [yfinance documentation](https://pypi.org/project/yfinance/)
# + [Tutorial in geeksforgeeks.org](https://www.geeksforgeeks.org/get-financial-data-from-yahoo-finance-with-python/)

# %% [markdown]
# + If required, install: `python -m pip install yfinance`.
# + To download the price history of a stock, first use the following setup:

# %%
pip install yfinance
# Out:
# Requirement already satisfied: yfinance in /opt/miniconda3/envs/dsi_participant/lib/python3.9/site-packages (0.2.52)
# Requirement already satisfied: pandas>=1.3.0 in /opt/miniconda3/envs/dsi_participant/lib/python3.9/site-packages (from yfinance) (2.2.3)
# Requirement already satisfied: numpy>=1.16.5 in /opt/miniconda3/envs/dsi_participant/lib/python3.9/site-packages (from yfinance) (2.0.1)
# Requirement already satisfied: requests>=2.31 in /opt/miniconda3/envs/dsi_participant/lib/python3.9/site-packages (from yfinance) (2.32.3)
# Requirement already satisfied: multitasking>=0.0.7 in /opt/miniconda3/envs/dsi_participant/lib/python3.9/site-packages (from yfinance) (0.0.11)
# Requirement already satisfied: lxml>=4.9.1 in /opt/miniconda3/envs/dsi_participant/lib/python3.9/site-packages (from yfinance) (5.3.0)
# Requirement already satisfied: platformdirs>=2.0.0 in /opt/miniconda3/envs/dsi_participant/lib/python3.9/site-packages (from yfinance) (4.3.6)
# Requirement already satisfied: pytz>=2022.5 in /opt/miniconda3/envs/dsi_participant/lib/python3.9/site-packages (from yfinance) (2025.1)
# Requirement already satisfied: frozendict>=2.3.4 in /opt/miniconda3/envs/dsi_participant/lib/python3.9/site-packages (from yfinance) (2.4.6)
# Requirement already satisfied: peewee>=3.16.2 in /opt/miniconda3/envs/dsi_participant/lib/python3.9/site-packages (from yfinance) (3.17.8)
# Requirement already satisfied: beautifulsoup4>=4.11.1 in /opt/miniconda3/envs/dsi_participant/lib/python3.9/site-packages (from yfinance) (4.12.3)
# Requirement already satisfied: html5lib>=1.1 in /opt/miniconda3/envs/dsi_participant/lib/python3.9/site-packages (from yfinance) (1.1)
# Requirement already satisfied: soupsieve>1.2 in /opt/miniconda3/envs/dsi_participant/lib/python3.9/site-packages (from beautifulsoup4>=4.11.1->yfinance) (2.6)
# Requirement already satisfied: six>=1.9 in /opt/miniconda3/envs/dsi_participant/lib/python3.9/site-packages (from html5lib>=1.1->yfinance) (1.16.0)
# Requirement already satisfied: webencodings in /opt/miniconda3/envs/dsi_participant/lib/python3.9/site-packages (from html5lib>=1.1->yfinance) (0.5.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in /opt/miniconda3/envs/dsi_participant/lib/python3.9/site-packages (from pandas>=1.3.0->yfinance) (2.9.0.post0)
# Requirement already satisfied: tzdata>=2022.7 in /opt/miniconda3/envs/dsi_participant/lib/python3.9/site-packages (from pandas>=1.3.0->yfinance) (2025.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/miniconda3/envs/dsi_participant/lib/python3.9/site-packages (from requests>=2.31->yfinance) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /opt/miniconda3/envs/dsi_participant/lib/python3.9/site-packages (from requests>=2.31->yfinance) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/miniconda3/envs/dsi_participant/lib/python3.9/site-packages (from requests>=2.31->yfinance) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/miniconda3/envs/dsi_participant/lib/python3.9/site-packages (from requests>=2.31->yfinance) (2025.1.31)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install pandas
# Out:
# Requirement already satisfied: pandas in /opt/miniconda3/envs/dsi_participant/lib/python3.9/site-packages (2.2.3)
# Requirement already satisfied: numpy>=1.22.4 in /opt/miniconda3/envs/dsi_participant/lib/python3.9/site-packages (from pandas) (2.0.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in /opt/miniconda3/envs/dsi_participant/lib/python3.9/site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /opt/miniconda3/envs/dsi_participant/lib/python3.9/site-packages (from pandas) (2025.1)
# Requirement already satisfied: tzdata>=2022.7 in /opt/miniconda3/envs/dsi_participant/lib/python3.9/site-packages (from pandas) (2025.1)
# Requirement already satisfied: six>=1.5 in /opt/miniconda3/envs/dsi_participant/lib/python3.9/site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import yfinance as yf
import os
import sys

sys.path.append(os.getenv('SRC_DIR'))

# %% [markdown]
# A few things to notice in the code chunk above:
#
# + Libraries are ordered from high-level to low-level libraries from the package manager (pip in this case, but could be conda, poetry, etc.)
# + The command `sys.path.append("../05_src/)` will add the `../05_src/` directory to the path in the Notebook's kernel. This way, we can use our modules as part of the notebook.
# + Local modules are imported at the end.
# + The function `get_logger()` is called with `__name__` as recommended by the documentation.

# %% [markdown]
# Now, to download the historical price data for a stock, we could use:

# %%
px = yf.download('AAPL', start = "2013-12-01", end = "2024-02-01")
px
# Out:
# [*********************100%***********************]  1 of 1 completed
# Price            Close        High         Low        Open     Volume
# Ticker            AAPL        AAPL        AAPL        AAPL       AAPL
# Date
# 2013-12-02   17.175095   17.583260   17.162320   17.386032  472544800
# 2013-12-03   17.645260   17.647130   17.376057   17.395375  450968000
# 2013-12-04   17.604143   17.734694   17.473903   17.619722  377809600
# 2013-12-05   17.694494   17.920077   17.648070   17.842494  447580000
# 2013-12-06   17.448977   17.658669   17.434957   17.628757  344352400
# ...                ...         ...         ...         ...        ...
# 2024-01-25  193.223389  195.313157  192.168559  194.268273   54822100
# 2024-01-26  191.481918  193.810507  191.004263  193.322905   44594000
# 2024-01-29  190.795273  191.262983  188.655761  191.073907   47145600
# 2024-01-30  187.123276  190.864955  186.556062  190.009147   55859400
# 2024-01-31  183.501022  186.187872  183.451278  186.128151   55467800
#
# [2558 rows x 5 columns]

# %% [markdown]
# ## Parametrize the download
#
# + Generally, we will look to separate every parameter and setting from functions.
# + If we had a few stocks, we could cycle through them. We need a place to store the list of tickers (a db or file, for example).
# + Store a csv file with a few stock tickers. The location of the file is a setting, the contents of this file are parameters.
# + Use **environment variables** to pass parameters.
#
# Start by getting a sample of Information Technology stock tickers by applying subindexing and converting the "ticker" column from a pandas object to a list.

# %%
# Load all tickers
ticker_file = os.getenv("TICKERS")
tickers = pd.read_csv(ticker_file)

# %% [markdown]
# We can subset our ticker data set using standard indexing techniques. A good reference for this type of data manipulation is Panda's [Documentation](https://pandas.pydata.org/docs/user_guide/indexing.html#indexing-and-selecting-data) and [Cookbook](https://pandas.pydata.org/docs/user_guide/cookbook.html#cookbook-selection).

# %%
idx_tech = tickers['GICS Sector'] == 'Information Technology'
tech_sector = tickers[idx_tech]

# %% [markdown]
# From the subset data frame, select one column and convert to list.

# %%
tech_tickers = tech_sector['ticker'].to_list()

# %%
tech_raw_dt = yf.download(tech_tickers, start = "2000-01-01", end = "2025-01-26")
# Out:
# [*********************100%***********************]  64 of 64 completed

# %% [markdown]
# The data that we downloaded combines several stocks and prices into a single row. We want to parse this arrangement into a dataframe that contains observations about a single stock on a given day per row. To do this, we can use the function [`stack()`](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.stack.html) and re-arrange the indices.

# %%
# First, check what tech_raw_dt.stack() looks like.
tech_raw_dt.stack(future_stack=True).reset_index()
# Out:
# Price        Date Ticker       Close        High         Low        Open  \
# 0      2000-01-03   AAPL    0.843076    0.847313    0.765877    0.789884
# 1      2000-01-03    ACN         NaN         NaN         NaN         NaN
# 2      2000-01-03   ADBE   16.274673   16.755622   15.948870   16.693564
# 3      2000-01-03    ADI   28.095680   29.244429   27.414219   29.127608
# 4      2000-01-03   ADSK    8.052903    8.354510    7.751296    8.203707
# ...           ...    ...         ...         ...         ...         ...
# 403451 2025-01-24    TXN  185.520004  191.500000  185.029999  190.000000
# 403452 2025-01-24    TYL  591.929993  594.969971  590.210022  591.400024
# 403453 2025-01-24   VRSN  210.729996  210.880005  206.009995  206.020004
# 403454 2025-01-24    WDC   67.410004   69.440002   67.360001   68.910004
# 403455 2025-01-24   ZBRA  414.609985  420.079987  413.739990  419.059998
#
# Price        Volume
# 0       535796800.0
# 1               NaN
# 2         7384400.0
# 3         3655600.0
# 4         2845600.0
# ...             ...
# 403451   15856600.0
# 403452     155300.0
# 403453     563300.0
# 403454    6046500.0
# 403455     258900.0
#
# [403456 rows x 7 columns]

# %%
tech_dt = (tech_raw_dt
           .stack(future_stack=True)
           .reset_index()
           .sort_values(['Ticker', 'Date']))
tech_dt.columns.name = None

# %% [markdown]
# # Storing Data in CSV

# %% [markdown]
# + We have some data. How do we store it?
# + We can compare two options, CSV and Parqruet, by measuring their performance:
#
#     - Time to save.
#     - Space required.

# %%
def get_dir_size(path='.'):
    '''Returns the total size of files contained in path.'''
    total = 0
    with os.scandir(path) as it:
        for entry in it:
            if entry.is_file():
                total += entry.stat().st_size
            elif entry.is_dir():
                total += get_dir_size(entry.path)
    return total

# %%
import time

# %%
temp = os.getenv("TEMP_DATA")
os.makedirs(temp, exist_ok=True)
stock_path = os.path.join(temp, "stock_px.csv")

# %%
start = time.time()
tech_dt.to_csv(stock_path, index = False)
end = time.time()

print(f'Writing to dt ({tech_dt.shape})csv took {end - start} seconds.')
print(f'Csv file size { os.path.getsize(stock_path)*1e-6 } MB')
# Out:
# Writing to dt ((403456, 7))csv took 1.2575268745422363 seconds.
# Csv file size 35.837714 MB

# %% [markdown]
# ## Save Data to Parquet
#
# ### Dask
#
# We can work with with large data sets and parquet files. In fact, recent versions of pandas support pyarrow data types and future versions will require a pyarrow backend. The pyarrow library is an interface between Python and the Appache Arrow project. The [parquet data format](https://parquet.apache.org/) and [Arrow](https://arrow.apache.org/docs/python/parquet.html) are projects of the Apache Foundation.
#
# However, Dask is much more than an interface to Arrow: Dask provides parallel and distributed computing on pandas-like dataframes. It is also relatively easy to use, bridging a gap between pandas and Spark.

# %%
# !pip install dask
# Out:
# Requirement already satisfied: dask in /opt/miniconda3/envs/dsi_participant/lib/python3.9/site-packages (2024.8.0)
# Requirement already satisfied: click>=8.1 in /opt/miniconda3/envs/dsi_participant/lib/python3.9/site-packages (from dask) (8.1.8)
# Requirement already satisfied: cloudpickle>=1.5.0 in /opt/miniconda3/envs/dsi_participant/lib/python3.9/site-packages (from dask) (3.1.1)
# Requirement already satisfied: fsspec>=2021.09.0 in /opt/miniconda3/envs/dsi_participant/lib/python3.9/site-packages (from dask) (2024.12.0)
# Requirement already satisfied: packaging>=20.0 in /opt/miniconda3/envs/dsi_participant/lib/python3.9/site-packages (from dask) (24.2)
# Requirement already satisfied: partd>=1.4.0 in /opt/miniconda3/envs/dsi_participant/lib/python3.9/site-packages (from dask) (1.4.2)
# Requirement already satisfied: pyyaml>=5.3.1 in /opt/miniconda3/envs/dsi_participant/lib/python3.9/site-packages (from dask) (6.0.2)
# Requirement already satisfied: toolz>=0.10.0 in /opt/miniconda3/envs/dsi_participant/lib/python3.9/site-packages (from dask) (1.0.0)
# Requirement already satisfied: importlib-metadata>=4.13.0 in /opt/miniconda3/envs/dsi_participant/lib/python3.9/site-packages (from dask) (8.5.0)
# Requirement already satisfied: zipp>=3.20 in /opt/miniconda3/envs/dsi_participant/lib/python3.9/site-packages (from importlib-metadata>=4.13.0->dask) (3.21.0)
# Requirement already satisfied: locket in /opt/miniconda3/envs/dsi_participant/lib/python3.9/site-packages (from partd>=1.4.0->dask) (1.0.0)

# %%
import dask.dataframe as dd
# Out:
# /opt/miniconda3/envs/dsi_participant/lib/python3.9/site-packages/dask/dataframe/__init__.py:42: FutureWarning:
# Dask dataframe query planning is disabled because dask-expr is not installed.
#
# You can install it with `pip install dask[dataframe]` or `conda install dask`.
# This will raise in a future version.
#
#   warnings.warn(msg, FutureWarning)

# %%
# !pip install pyarrow
# Out:
# Requirement already satisfied: pyarrow in /opt/miniconda3/envs/dsi_participant/lib/python3.9/site-packages (19.0.0)

# %%
px_dd = dd.from_pandas(tech_dt, npartitions = len(tech_tickers))
parquet_path = os.path.join(temp, "stock_px.parquet")

start = time.time()
px_dd.to_parquet(parquet_path, engine = "pyarrow")
end = time.time()

print(f'Writing dd ({tech_dt.shape}) to parquet took {end - start} seconds.')
print(f'Parquet file size { get_dir_size(parquet_path)*1e-6 } MB')
# Out:
# Writing dd ((403456, 7)) to parquet took 0.20774507522583008 seconds.
# Parquet file size 16.991736 MB

# %% [markdown]
# ### Parquet files and Dask Dataframes
#
# + Parquet files are immutable: once written, they cannot be modified.
# + Dask DataFrames are a useful implementation to manipulate data stored in parquets.
# + Parquet and Dask are not the same: parquet is a file format that can be accessed by many applications and programming languages (Python, R, PowerBI, etc.), while Dask is a package in Python to work with large datasets using distributed computation.
# + **Dask is not for everything** (see [Dask DataFrames Best Practices](https://docs.dask.org/en/stable/dataframe-best-practices.html)).
#
#     - Consider cases suchas small to large joins, where the small dataframe fits in memory, but the large one does not.
#     - If possible, use pandas: reduce, then use pandas.
#     - Pandas performance tips apply to Dask.
#     - Use the index: it is beneficial to have a well-defined index in Dask DataFrames, as it may speed up searching (filtering) the data. A one-dimensional index is allowed.
#     - Avoid (or minimize) full-data shuffling: indexing is an expensive operations.
#     - Some joins are more expensive than others.
#
#         * Not expensive:
#
#             - Join a Dask DataFrame with a pandas DataFrame.
#             - Join a Dask DataFrame with another Dask DataFrame of a single partition.
#             - Join Dask DataFrames along their indexes.
#
#         * Expensive:
#
#             - Join Dask DataFrames along columns that are not their index.

# %% [markdown]
# # How do we store prices?
#
# + We can store our data as a single blob. This can be difficult to maintain, especially because parquet files are immutable.
# + Strategy: organize data files by ticker and date. Update only latest month.

# %%
# CLean up before start
PRICE_DATA = os.getenv("PRICE_DATA")
import shutil
if os.path.exists(PRICE_DATA):
    shutil.rmtree(PRICE_DATA)

# %%
for ticker in tech_dt['Ticker'].unique():
    ticker_dt = tech_dt[tech_dt['Ticker'] == ticker]
    ticker_dt = ticker_dt.assign(Year = ticker_dt.Date.dt.year)
    for yr in ticker_dt['Year'].unique():
        yr_dd = dd.from_pandas(ticker_dt[ticker_dt['Year'] == yr],2)
        yr_path = os.path.join(PRICE_DATA, ticker, f"{ticker}_{yr}")
        os.makedirs(os.path.dirname(yr_path), exist_ok=True)
        yr_dd.to_parquet(yr_path, engine = "pyarrow")

# %% [markdown]
# Why would we want to store data this way?
#
# + Easier to maintain. We do not update old data, only recent data.
# + We can also access all files as follows.

# %% [markdown]
# # Load, Transform and Save

# %% [markdown]
# ## Load
#
# + Parquet files can be read individually or as a collection.
# + `dd.read_parquet()` can take a list (collection) of files as input.
# + Use `glob` to get the collection of files.

# %%
from glob import glob

parquet_files = glob(os.path.join(PRICE_DATA, "**/*.parquet"), recursive = True)
dd_px = dd.read_parquet(parquet_files).set_index("Ticker")

# %% [markdown]
# ## Transform
#
# + This transformation step will create a *Features* data set. In our case, features will be stock returns (we obtained prices).
# + Dask dataframes work like pandas dataframes: in particular, we can perform groupby and apply operations.
# + Notice the use of [an anonymous (lambda) function](https://realpython.com/python-lambda/) in the apply statement.

# %%
dd_shift = dd_px.groupby('Ticker', group_keys=False).apply(
    lambda x: x.assign(Close_lag_1 = x['Close'].shift(1))
)
# Out:
# /var/folders/nc/pbf0pj7114jg0dltbbtyzj0m0000gn/T/ipykernel_35955/3086392435.py:1: UserWarning: `meta` is not specified, inferred from partial data. Please provide `meta` if the result is unexpected.
#   Before: .apply(func)
#   After:  .apply(func, meta={'x': 'f8', 'y': 'f8'}) for dataframe result
#   or:     .apply(func, meta=('x', 'f8'))            for series result
#   dd_shift = dd_px.groupby('Ticker', group_keys=False).apply(

# %%
dd_rets = dd_shift.assign(
    Returns = lambda x: x['Close']/x['Close_lag_1'] - 1
)

# %% [markdown]
# ## Lazy Exection
#
# What does `dd_rets` contain?

# %%
# !pip install jinja2
# Out:
# Requirement already satisfied: jinja2 in /opt/miniconda3/envs/dsi_participant/lib/python3.9/site-packages (3.1.5)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/miniconda3/envs/dsi_participant/lib/python3.9/site-packages (from jinja2) (3.0.2)

# %%
dd_rets
# Out:
# Dask DataFrame Structure:
#                           Date    Close     High      Low     Open   Volume   Year Close_lag_1  Returns
# npartitions=64
# AAPL            datetime64[ns]  float64  float64  float64  float64  float64  int32     float64  float64
# ACN                        ...      ...      ...      ...      ...      ...    ...         ...      ...
# ...                        ...      ...      ...      ...      ...      ...    ...         ...      ...
# ZBRA                       ...      ...      ...      ...      ...      ...    ...         ...      ...
# ZBRA                       ...      ...      ...      ...      ...      ...    ...         ...      ...
# Dask Name: assign, 14 graph layers

# %% [markdown]
# + Dask is a lazy execution framework: commands will not execute until they are required.
# + To trigger an execution in dask use `.compute()`.

# %%
dd_rets.compute()
# Out:
#              Date       Close        High         Low        Open  \
# Ticker
# AAPL   2000-01-03    0.843076    0.847313    0.765877    0.789884
# AAPL   2000-01-04    0.771997    0.833191    0.762111    0.815304
# AAPL   2000-01-05    0.783294    0.832720    0.775762    0.781411
# AAPL   2000-01-06    0.715509    0.805889    0.715509    0.799299
# AAPL   2000-01-07    0.749401    0.760699    0.719275    0.726806
# ...           ...         ...         ...         ...         ...
# ZBRA   2025-01-17  405.709991  407.290009  402.290009  406.040009
# ZBRA   2025-01-21  418.070007  419.850006  407.619995  407.619995
# ZBRA   2025-01-22  420.570007  427.760010  419.589996  425.239990
# ZBRA   2025-01-23  421.109985  422.290009  414.450012  417.619995
# ZBRA   2025-01-24  414.609985  420.079987  413.739990  419.059998
#
#              Volume  Year  Close_lag_1   Returns
# Ticker
# AAPL    535796800.0  2000          NaN       NaN
# AAPL    512377600.0  2000     0.843076 -0.084310
# AAPL    778321600.0  2000     0.771997  0.014633
# AAPL    767972800.0  2000     0.783294 -0.086538
# AAPL    460734400.0  2000     0.715509  0.047369
# ...             ...   ...          ...       ...
# ZBRA       270600.0  2025   402.720001  0.007424
# ZBRA       446000.0  2025   405.709991  0.030465
# ZBRA       497500.0  2025   418.070007  0.005980
# ZBRA       377100.0  2025   420.570007  0.001284
# ZBRA       258900.0  2025   421.109985 -0.015435
#
# [403456 rows x 9 columns]

# %% [markdown]
# ## Save
#
# + Apply transformations to calculate daily returns
# + Store the enriched data, the silver dataset, in a new directory.
# + Should we keep the same namespace? All columns?

# %%
# CLean up before save
FEATURES_DATA = os.getenv("FEATURES_DATA")
if os.path.exists(FEATURES_DATA):
    shutil.rmtree(FEATURES_DATA)
dd_rets.to_parquet(FEATURES_DATA, overwrite = True)

# %% [markdown]
# # Optional: from Jupyter to Command Line
#
# + We have drafted our code in a Jupyter Notebook.
# + Finalized code should be written in Python modules.
#
# ## Object Oriented vs Functional Programming
#
# + We can use classes to keep parameters and functions together.
# + We *could* use Object Oriented Programming, but parallelization of data manipulation and modelling tasks benefit from *Functional Programming*.
# + An Idea:
#
#     - [Data Oriented Programming](https://blog.klipse.tech/dop/2022/06/22/principles-of-dop.html).
#     - Use the class to bundle together parameters and functions.
#     - Use stateless operations and treat all data objects as immutable (we do not modify them, we overwrite them).
#     - Take advantage of [`@staticmethod`](https://realpython.com/instance-class-and-static-methods-demystified/).
#
# The code is in `./05_src/`.

# %% [markdown]
# Our original design was:
#
# ![](./images/02_target_pipeline_manager.png)

# %% [markdown]
# The `DataManager` class in `./05_src/data_manager.py` is a simple implementation of the ideas and code discussed in this notebook. The lines below will download data for about 500 stocks from the S&P500. Using this data a few features will be created and stored in the features data set.
#
# First, instantiate an object of class `DataManager`.

# %%
from data_manager import DataManager
dm = DataManager()

# %% [markdown]
# Download all prices.

# %%
dm.download_all()
# Out:
# 2025-01-31 13:55:46,536, data_manager.py, 42, INFO, Getting price data for all tickers.
# 2025-01-31 13:55:46,537, data_manager.py, 51, INFO, Getting tickers from ../../05_src/data/tickers/sp500_wiki.csv
# 2025-01-31 13:55:46,545, data_manager.py, 57, INFO, Processing all tickers
# 2025-01-31 13:55:46,546, data_manager.py, 70, INFO, Processing ticker ['MMM', 'AOS', 'ABT', 'ABBV', 'ACN', 'ADBE', 'AMD', 'AES', 'AFL', 'A', 'APD', 'ABNB', 'AKAM', 'ALB', 'ARE', 'ALGN', 'ALLE', 'LNT', 'ALL', 'GOOGL', 'GOOG', 'MO', 'AMZN', 'AMCR', 'AEE', 'AAL', 'AEP', 'AXP', 'AIG', 'AMT', 'AWK', 'AMP', 'AME', 'AMGN', 'APH', 'ADI', 'ANSS', 'AON', 'APA', 'AAPL', 'AMAT', 'APTV', 'ACGL', 'ADM', 'ANET', 'AJG', 'AIZ', 'T', 'ATO', 'ADSK', 'ADP', 'AZO', 'AVB', 'AVY', 'AXON', 'BKR', 'BALL', 'BAC', 'BK', 'BBWI', 'BAX', 'BDX', 'BRK.B', 'BBY', 'BIO', 'TECH', 'BIIB', 'BLK', 'BX', 'BA', 'BKNG', 'BWA', 'BXP', 'BSX', 'BMY', 'AVGO', 'BR', 'BRO', 'BF.B', 'BLDR', 'BG', 'CDNS', 'CZR', 'CPT', 'CPB', 'COF', 'CAH', 'KMX', 'CCL', 'CARR', 'CTLT', 'CAT', 'CBOE', 'CBRE', 'CDW', 'CE', 'COR', 'CNC', 'CNP', 'CF', 'CHRW', 'CRL', 'SCHW', 'CHTR', 'CVX', 'CMG', 'CB', 'CHD', 'CI', 'CINF', 'CTAS', 'CSCO', 'C', 'CFG', 'CLX', 'CME', 'CMS', 'KO', 'CTSH', 'CL', 'CMCSA', 'CMA', 'CAG', 'COP', 'ED', 'STZ', 'CEG', 'COO', 'CPRT', 'GLW', 'CTVA', 'CSGP', 'COST', 'CTRA', 'CCI', 'CSX', 'CMI', 'CVS', 'DHR', 'DRI', 'DVA', 'DAY', 'DE', 'DAL', 'XRAY', 'DVN', 'DXCM', 'FANG', 'DLR', 'DFS', 'DG', 'DLTR', 'D', 'DPZ', 'DOV', 'DOW', 'DHI', 'DTE', 'DUK', 'DD', 'EMN', 'ETN', 'EBAY', 'ECL', 'EIX', 'EW', 'EA', 'ELV', 'LLY', 'EMR', 'ENPH', 'ETR', 'EOG', 'EPAM', 'EQT', 'EFX', 'EQIX', 'EQR', 'ESS', 'EL', 'ETSY', 'EG', 'EVRG', 'ES', 'EXC', 'EXPE', 'EXPD', 'EXR', 'XOM', 'FFIV', 'FDS', 'FICO', 'FAST', 'FRT', 'FDX', 'FIS', 'FITB', 'FSLR', 'FE', 'FI', 'FLT', 'FMC', 'F', 'FTNT', 'FTV', 'FOXA', 'FOX', 'BEN', 'FCX', 'GRMN', 'IT', 'GEHC', 'GEN', 'GNRC', 'GD', 'GE', 'GIS', 'GM', 'GPC', 'GILD', 'GPN', 'GL', 'GS', 'HAL', 'HIG', 'HAS', 'HCA', 'PEAK', 'HSIC', 'HSY', 'HES', 'HPE', 'HLT', 'HOLX', 'HD', 'HON', 'HRL', 'HST', 'HWM', 'HPQ', 'HUBB', 'HUM', 'HBAN', 'HII', 'IBM', 'IEX', 'IDXX', 'ITW', 'ILMN', 'INCY', 'IR', 'PODD', 'INTC', 'ICE', 'IFF', 'IP', 'IPG', 'INTU', 'ISRG', 'IVZ', 'INVH', 'IQV', 'IRM', 'JBHT', 'JBL', 'JKHY', 'J', 'JNJ', 'JCI', 'JPM', 'JNPR', 'K', 'KVUE', 'KDP', 'KEY', 'KEYS', 'KMB', 'KIM', 'KMI', 'KLAC', 'KHC', 'KR', 'LHX', 'LH', 'LRCX', 'LW', 'LVS', 'LDOS', 'LEN', 'LIN', 'LYV', 'LKQ', 'LMT', 'L', 'LOW', 'LULU', 'LYB', 'MTB', 'MRO', 'MPC', 'MKTX', 'MAR', 'MMC', 'MLM', 'MAS', 'MA', 'MTCH', 'MKC', 'MCD', 'MCK', 'MDT', 'MRK', 'META', 'MET', 'MTD', 'MGM', 'MCHP', 'MU', 'MSFT', 'MAA', 'MRNA', 'MHK', 'MOH', 'TAP', 'MDLZ', 'MPWR', 'MNST', 'MCO', 'MS', 'MOS', 'MSI', 'MSCI', 'NDAQ', 'NTAP', 'NFLX', 'NEM', 'NWSA', 'NWS', 'NEE', 'NKE', 'NI', 'NDSN', 'NSC', 'NTRS', 'NOC', 'NCLH', 'NRG', 'NUE', 'NVDA', 'NVR', 'NXPI', 'ORLY', 'OXY', 'ODFL', 'OMC', 'ON', 'OKE', 'ORCL', 'OTIS', 'PCAR', 'PKG', 'PANW', 'PARA', 'PH', 'PAYX', 'PAYC', 'PYPL', 'PNR', 'PEP', 'PFE', 'PCG', 'PM', 'PSX', 'PNW', 'PXD', 'PNC', 'POOL', 'PPG', 'PPL', 'PFG', 'PG', 'PGR', 'PLD', 'PRU', 'PEG', 'PTC', 'PSA', 'PHM', 'QRVO', 'PWR', 'QCOM', 'DGX', 'RL', 'RJF', 'RTX', 'O', 'REG', 'REGN', 'RF', 'RSG', 'RMD', 'RVTY', 'RHI', 'ROK', 'ROL', 'ROP', 'ROST', 'RCL', 'SPGI', 'CRM', 'SBAC', 'SLB', 'STX', 'SRE', 'NOW', 'SHW', 'SPG', 'SWKS', 'SJM', 'SNA', 'SO', 'LUV', 'SWK', 'SBUX', 'STT', 'STLD', 'STE', 'SYK', 'SYF', 'SNPS', 'SYY', 'TMUS', 'TROW', 'TTWO', 'TPR', 'TRGP', 'TGT', 'TEL', 'TDY', 'TFX', 'TER', 'TSLA', 'TXN', 'TXT', 'TMO', 'TJX', 'TSCO', 'TT', 'TDG', 'TRV', 'TRMB', 'TFC', 'TYL', 'TSN', 'USB', 'UBER', 'UDR', 'ULTA', 'UNP', 'UAL', 'UPS', 'URI', 'UNH', 'UHS', 'VLO', 'VTR', 'VLTO', 'VRSN', 'VRSK', 'VZ', 'VRTX', 'VFC', 'VTRS', 'VICI', 'V', 'VMC', 'WRB', 'WAB', 'WBA', 'WMT', 'DIS', 'WBD', 'WM', 'WAT', 'WEC', 'WFC', 'WELL', 'WST', 'WDC', 'WRK', 'WY', 'WHR', 'WMB', 'WTW', 'GWW', 'WYNN', 'XEL', 'XYL', 'YUM', 'ZBRA', 'ZBH', 'ZION', 'ZTS']
# 2025-01-31 13:55:46,547, data_manager.py, 100, INFO, Getting stock price data for ['MMM', 'AOS', 'ABT', 'ABBV', 'ACN', 'ADBE', 'AMD', 'AES', 'AFL', 'A', 'APD', 'ABNB', 'AKAM', 'ALB', 'ARE', 'ALGN', 'ALLE', 'LNT', 'ALL', 'GOOGL', 'GOOG', 'MO', 'AMZN', 'AMCR', 'AEE', 'AAL', 'AEP', 'AXP', 'AIG', 'AMT', 'AWK', 'AMP', 'AME', 'AMGN', 'APH', 'ADI', 'ANSS', 'AON', 'APA', 'AAPL', 'AMAT', 'APTV', 'ACGL', 'ADM', 'ANET', 'AJG', 'AIZ', 'T', 'ATO', 'ADSK', 'ADP', 'AZO', 'AVB', 'AVY', 'AXON', 'BKR', 'BALL', 'BAC', 'BK', 'BBWI', 'BAX', 'BDX', 'BRK.B', 'BBY', 'BIO', 'TECH', 'BIIB', 'BLK', 'BX', 'BA', 'BKNG', 'BWA', 'BXP', 'BSX', 'BMY', 'AVGO', 'BR', 'BRO', 'BF.B', 'BLDR', 'BG', 'CDNS', 'CZR', 'CPT', 'CPB', 'COF', 'CAH', 'KMX', 'CCL', 'CARR', 'CTLT', 'CAT', 'CBOE', 'CBRE', 'CDW', 'CE', 'COR', 'CNC', 'CNP', 'CF', 'CHRW', 'CRL', 'SCHW', 'CHTR', 'CVX', 'CMG', 'CB', 'CHD', 'CI', 'CINF', 'CTAS', 'CSCO', 'C', 'CFG', 'CLX', 'CME', 'CMS', 'KO', 'CTSH', 'CL', 'CMCSA', 'CMA', 'CAG', 'COP', 'ED', 'STZ', 'CEG', 'COO', 'CPRT', 'GLW', 'CTVA', 'CSGP', 'COST', 'CTRA', 'CCI', 'CSX', 'CMI', 'CVS', 'DHR', 'DRI', 'DVA', 'DAY', 'DE', 'DAL', 'XRAY', 'DVN', 'DXCM', 'FANG', 'DLR', 'DFS', 'DG', 'DLTR', 'D', 'DPZ', 'DOV', 'DOW', 'DHI', 'DTE', 'DUK', 'DD', 'EMN', 'ETN', 'EBAY', 'ECL', 'EIX', 'EW', 'EA', 'ELV', 'LLY', 'EMR', 'ENPH', 'ETR', 'EOG', 'EPAM', 'EQT', 'EFX', 'EQIX', 'EQR', 'ESS', 'EL', 'ETSY', 'EG', 'EVRG', 'ES', 'EXC', 'EXPE', 'EXPD', 'EXR', 'XOM', 'FFIV', 'FDS', 'FICO', 'FAST', 'FRT', 'FDX', 'FIS', 'FITB', 'FSLR', 'FE', 'FI', 'FLT', 'FMC', 'F', 'FTNT', 'FTV', 'FOXA', 'FOX', 'BEN', 'FCX', 'GRMN', 'IT', 'GEHC', 'GEN', 'GNRC', 'GD', 'GE', 'GIS', 'GM', 'GPC', 'GILD', 'GPN', 'GL', 'GS', 'HAL', 'HIG', 'HAS', 'HCA', 'PEAK', 'HSIC', 'HSY', 'HES', 'HPE', 'HLT', 'HOLX', 'HD', 'HON', 'HRL', 'HST', 'HWM', 'HPQ', 'HUBB', 'HUM', 'HBAN', 'HII', 'IBM', 'IEX', 'IDXX', 'ITW', 'ILMN', 'INCY', 'IR', 'PODD', 'INTC', 'ICE', 'IFF', 'IP', 'IPG', 'INTU', 'ISRG', 'IVZ', 'INVH', 'IQV', 'IRM', 'JBHT', 'JBL', 'JKHY', 'J', 'JNJ', 'JCI', 'JPM', 'JNPR', 'K', 'KVUE', 'KDP', 'KEY', 'KEYS', 'KMB', 'KIM', 'KMI', 'KLAC', 'KHC', 'KR', 'LHX', 'LH', 'LRCX', 'LW', 'LVS', 'LDOS', 'LEN', 'LIN', 'LYV', 'LKQ', 'LMT', 'L', 'LOW', 'LULU', 'LYB', 'MTB', 'MRO', 'MPC', 'MKTX', 'MAR', 'MMC', 'MLM', 'MAS', 'MA', 'MTCH', 'MKC', 'MCD', 'MCK', 'MDT', 'MRK', 'META', 'MET', 'MTD', 'MGM', 'MCHP', 'MU', 'MSFT', 'MAA', 'MRNA', 'MHK', 'MOH', 'TAP', 'MDLZ', 'MPWR', 'MNST', 'MCO', 'MS', 'MOS', 'MSI', 'MSCI', 'NDAQ', 'NTAP', 'NFLX', 'NEM', 'NWSA', 'NWS', 'NEE', 'NKE', 'NI', 'NDSN', 'NSC', 'NTRS', 'NOC', 'NCLH', 'NRG', 'NUE', 'NVDA', 'NVR', 'NXPI', 'ORLY', 'OXY', 'ODFL', 'OMC', 'ON', 'OKE', 'ORCL', 'OTIS', 'PCAR', 'PKG', 'PANW', 'PARA', 'PH', 'PAYX', 'PAYC', 'PYPL', 'PNR', 'PEP', 'PFE', 'PCG', 'PM', 'PSX', 'PNW', 'PXD', 'PNC', 'POOL', 'PPG', 'PPL', 'PFG', 'PG', 'PGR', 'PLD', 'PRU', 'PEG', 'PTC', 'PSA', 'PHM', 'QRVO', 'PWR', 'QCOM', 'DGX', 'RL', 'RJF', 'RTX', 'O', 'REG', 'REGN', 'RF', 'RSG', 'RMD', 'RVTY', 'RHI', 'ROK', 'ROL', 'ROP', 'ROST', 'RCL', 'SPGI', 'CRM', 'SBAC', 'SLB', 'STX', 'SRE', 'NOW', 'SHW', 'SPG', 'SWKS', 'SJM', 'SNA', 'SO', 'LUV', 'SWK', 'SBUX', 'STT', 'STLD', 'STE', 'SYK', 'SYF', 'SNPS', 'SYY', 'TMUS', 'TROW', 'TTWO', 'TPR', 'TRGP', 'TGT', 'TEL', 'TDY', 'TFX', 'TER', 'TSLA', 'TXN', 'TXT', 'TMO', 'TJX', 'TSCO', 'TT', 'TDG', 'TRV', 'TRMB', 'TFC', 'TYL', 'TSN', 'USB', 'UBER', 'UDR', 'ULTA', 'UNP', 'UAL', 'UPS', 'URI', 'UNH', 'UHS', 'VLO', 'VTR', 'VLTO', 'VRSN', 'VRSK', 'VZ', 'VRTX', 'VFC', 'VTRS', 'VICI', 'V', 'VMC', 'WRB', 'WAB', 'WBA', 'WMT', 'DIS', 'WBD', 'WM', 'WAT', 'WEC', 'WFC', 'WELL', 'WST', 'WDC', 'WRK', 'WY', 'WHR', 'WMB', 'WTW', 'GWW', 'WYNN', 'XEL', 'XYL', 'YUM', 'ZBRA', 'ZBH', 'ZION', 'ZTS'] from 2000-01-01 to 2025-01-31
# [*********************100%***********************]  503 of 503 completed
#
# 7 Failed downloads:
# ['BRK.B', 'MRO', 'WRK', 'PXD', 'FLT', 'PEAK']: YFTzMissingError('$%ticker%: possibly delisted; no timezone found')
# ['BF.B']: YFPricesMissingError('$%ticker%: possibly delisted; no price data found  (1d 2000-01-01 -> 2025-01-31)')
# 2025-01-31 13:56:18,232, data_manager.py, 80, INFO, Saving data by year
# 2025-01-31 13:56:18,395, data_manager.py, 83, INFO, Saving data for A
# 2025-01-31 13:56:19,004, data_manager.py, 83, INFO, Saving data for AAL
# 2025-01-31 13:56:19,615, data_manager.py, 83, INFO, Saving data for AAPL
# 2025-01-31 13:56:20,241, data_manager.py, 83, INFO, Saving data for ABBV
# 2025-01-31 13:56:20,839, data_manager.py, 83, INFO, Saving data for ABNB
# 2025-01-31 13:56:21,431, data_manager.py, 83, INFO, Saving data for ABT
# 2025-01-31 13:56:22,112, data_manager.py, 83, INFO, Saving data for ACGL
# 2025-01-31 13:56:22,754, data_manager.py, 83, INFO, Saving data for ACN
# 2025-01-31 13:56:23,402, data_manager.py, 83, INFO, Saving data for ADBE
# 2025-01-31 13:56:24,060, data_manager.py, 83, INFO, Saving data for ADI
# 2025-01-31 13:56:24,648, data_manager.py, 83, INFO, Saving data for ADM
# 2025-01-31 13:56:25,242, data_manager.py, 83, INFO, Saving data for ADP
# 2025-01-31 13:56:25,852, data_manager.py, 83, INFO, Saving data for ADSK
# 2025-01-31 13:56:26,472, data_manager.py, 83, INFO, Saving data for AEE
# 2025-01-31 13:56:27,069, data_manager.py, 83, INFO, Saving data for AEP
# 2025-01-31 13:56:27,717, data_manager.py, 83, INFO, Saving data for AES
# 2025-01-31 13:56:28,300, data_manager.py, 83, INFO, Saving data for AFL
# 2025-01-31 13:56:28,944, data_manager.py, 83, INFO, Saving data for AIG
# 2025-01-31 13:56:29,524, data_manager.py, 83, INFO, Saving data for AIZ
# 2025-01-31 13:56:30,109, data_manager.py, 83, INFO, Saving data for AJG
# 2025-01-31 13:56:30,697, data_manager.py, 83, INFO, Saving data for AKAM
# 2025-01-31 13:56:31,353, data_manager.py, 83, INFO, Saving data for ALB
# 2025-01-31 13:56:32,019, data_manager.py, 83, INFO, Saving data for ALGN
# 2025-01-31 13:56:32,606, data_manager.py, 83, INFO, Saving data for ALL
# 2025-01-31 13:56:33,247, data_manager.py, 83, INFO, Saving data for ALLE
# 2025-01-31 13:56:33,912, data_manager.py, 83, INFO, Saving data for AMAT
# 2025-01-31 13:56:34,525, data_manager.py, 83, INFO, Saving data for AMCR
# 2025-01-31 13:56:35,143, data_manager.py, 83, INFO, Saving data for AMD
# 2025-01-31 13:56:35,761, data_manager.py, 83, INFO, Saving data for AME
# 2025-01-31 13:56:36,398, data_manager.py, 83, INFO, Saving data for AMGN
# 2025-01-31 13:56:37,078, data_manager.py, 83, INFO, Saving data for AMP
# 2025-01-31 13:56:37,737, data_manager.py, 83, INFO, Saving data for AMT
# 2025-01-31 13:56:38,343, data_manager.py, 83, INFO, Saving data for AMZN
# 2025-01-31 13:56:38,998, data_manager.py, 83, INFO, Saving data for ANET
# 2025-01-31 13:56:39,735, data_manager.py, 83, INFO, Saving data for ANSS
# 2025-01-31 13:56:40,433, data_manager.py, 83, INFO, Saving data for AON
# 2025-01-31 13:56:41,093, data_manager.py, 83, INFO, Saving data for AOS
# 2025-01-31 13:56:41,885, data_manager.py, 83, INFO, Saving data for APA
# 2025-01-31 13:56:42,523, data_manager.py, 83, INFO, Saving data for APD
# 2025-01-31 13:56:43,119, data_manager.py, 83, INFO, Saving data for APH
# 2025-01-31 13:56:43,831, data_manager.py, 83, INFO, Saving data for APTV
# 2025-01-31 13:56:44,444, data_manager.py, 83, INFO, Saving data for ARE
# 2025-01-31 13:56:45,200, data_manager.py, 83, INFO, Saving data for ATO
# 2025-01-31 13:56:45,824, data_manager.py, 83, INFO, Saving data for AVB
# 2025-01-31 13:56:46,460, data_manager.py, 83, INFO, Saving data for AVGO
# 2025-01-31 13:56:48,185, data_manager.py, 83, INFO, Saving data for AVY
# 2025-01-31 13:56:48,904, data_manager.py, 83, INFO, Saving data for AWK
# 2025-01-31 13:56:49,542, data_manager.py, 83, INFO, Saving data for AXON
# 2025-01-31 13:56:50,208, data_manager.py, 83, INFO, Saving data for AXP
# 2025-01-31 13:56:50,949, data_manager.py, 83, INFO, Saving data for AZO
# 2025-01-31 13:56:52,168, data_manager.py, 83, INFO, Saving data for BA
# 2025-01-31 13:56:52,809, data_manager.py, 83, INFO, Saving data for BAC
# 2025-01-31 13:56:53,425, data_manager.py, 83, INFO, Saving data for BALL
# 2025-01-31 13:56:54,064, data_manager.py, 83, INFO, Saving data for BAX
# 2025-01-31 13:56:54,696, data_manager.py, 83, INFO, Saving data for BBWI
# 2025-01-31 13:56:55,352, data_manager.py, 83, INFO, Saving data for BBY
# 2025-01-31 13:56:55,985, data_manager.py, 83, INFO, Saving data for BDX
# 2025-01-31 13:56:56,558, data_manager.py, 83, INFO, Saving data for BEN
# 2025-01-31 13:56:57,218, data_manager.py, 83, INFO, Saving data for BF.B
# 2025-01-31 13:56:57,829, data_manager.py, 83, INFO, Saving data for BG
# 2025-01-31 13:56:58,425, data_manager.py, 83, INFO, Saving data for BIIB
# 2025-01-31 13:56:59,020, data_manager.py, 83, INFO, Saving data for BIO
# 2025-01-31 13:56:59,605, data_manager.py, 83, INFO, Saving data for BK
# 2025-01-31 13:57:00,167, data_manager.py, 83, INFO, Saving data for BKNG
# 2025-01-31 13:57:00,822, data_manager.py, 83, INFO, Saving data for BKR
# 2025-01-31 13:57:01,529, data_manager.py, 83, INFO, Saving data for BLDR
# 2025-01-31 13:57:02,132, data_manager.py, 83, INFO, Saving data for BLK
# 2025-01-31 13:57:02,754, data_manager.py, 83, INFO, Saving data for BMY
# 2025-01-31 13:57:03,352, data_manager.py, 83, INFO, Saving data for BR
# 2025-01-31 13:57:04,130, data_manager.py, 83, INFO, Saving data for BRK.B
# 2025-01-31 13:57:04,748, data_manager.py, 83, INFO, Saving data for BRO
# 2025-01-31 13:57:05,380, data_manager.py, 83, INFO, Saving data for BSX
# 2025-01-31 13:57:06,009, data_manager.py, 83, INFO, Saving data for BWA
# 2025-01-31 13:57:06,604, data_manager.py, 83, INFO, Saving data for BX
# 2025-01-31 13:57:07,696, data_manager.py, 83, INFO, Saving data for BXP
# 2025-01-31 13:57:08,356, data_manager.py, 83, INFO, Saving data for C
# 2025-01-31 13:57:09,118, data_manager.py, 83, INFO, Saving data for CAG
# 2025-01-31 13:57:09,738, data_manager.py, 83, INFO, Saving data for CAH
# 2025-01-31 13:57:10,539, data_manager.py, 83, INFO, Saving data for CARR
# 2025-01-31 13:57:11,139, data_manager.py, 83, INFO, Saving data for CAT
# 2025-01-31 13:57:12,051, data_manager.py, 83, INFO, Saving data for CB
# 2025-01-31 13:57:12,986, data_manager.py, 83, INFO, Saving data for CBOE
# 2025-01-31 13:57:14,016, data_manager.py, 83, INFO, Saving data for CBRE
# 2025-01-31 13:57:14,697, data_manager.py, 83, INFO, Saving data for CCI
# 2025-01-31 13:57:15,312, data_manager.py, 83, INFO, Saving data for CCL
# 2025-01-31 13:57:16,018, data_manager.py, 83, INFO, Saving data for CDNS
# 2025-01-31 13:57:16,696, data_manager.py, 83, INFO, Saving data for CDW
# 2025-01-31 13:57:17,348, data_manager.py, 83, INFO, Saving data for CE
# 2025-01-31 13:57:18,054, data_manager.py, 83, INFO, Saving data for CEG
# 2025-01-31 13:57:18,744, data_manager.py, 83, INFO, Saving data for CF
# 2025-01-31 13:57:19,366, data_manager.py, 83, INFO, Saving data for CFG
# 2025-01-31 13:57:20,133, data_manager.py, 83, INFO, Saving data for CHD
# 2025-01-31 13:57:20,763, data_manager.py, 83, INFO, Saving data for CHRW
# 2025-01-31 13:57:21,385, data_manager.py, 83, INFO, Saving data for CHTR
# 2025-01-31 13:57:22,030, data_manager.py, 83, INFO, Saving data for CI
# 2025-01-31 13:57:22,667, data_manager.py, 83, INFO, Saving data for CINF
# 2025-01-31 13:57:23,307, data_manager.py, 83, INFO, Saving data for CL
# 2025-01-31 13:57:23,963, data_manager.py, 83, INFO, Saving data for CLX
# 2025-01-31 13:57:24,556, data_manager.py, 83, INFO, Saving data for CMA
# 2025-01-31 13:57:25,234, data_manager.py, 83, INFO, Saving data for CMCSA
# 2025-01-31 13:57:25,848, data_manager.py, 83, INFO, Saving data for CME
# 2025-01-31 13:57:26,442, data_manager.py, 83, INFO, Saving data for CMG
# 2025-01-31 13:57:27,012, data_manager.py, 83, INFO, Saving data for CMI
# 2025-01-31 13:57:27,608, data_manager.py, 83, INFO, Saving data for CMS
# 2025-01-31 13:57:28,225, data_manager.py, 83, INFO, Saving data for CNC
# 2025-01-31 13:57:28,907, data_manager.py, 83, INFO, Saving data for CNP
# 2025-01-31 13:57:29,577, data_manager.py, 83, INFO, Saving data for COF
# 2025-01-31 13:57:30,229, data_manager.py, 83, INFO, Saving data for COO
# 2025-01-31 13:57:30,882, data_manager.py, 83, INFO, Saving data for COP
# 2025-01-31 13:57:31,526, data_manager.py, 83, INFO, Saving data for COR
# 2025-01-31 13:57:32,143, data_manager.py, 83, INFO, Saving data for COST
# 2025-01-31 13:57:32,797, data_manager.py, 83, INFO, Saving data for CPB
# 2025-01-31 13:57:33,365, data_manager.py, 83, INFO, Saving data for CPRT
# 2025-01-31 13:57:33,947, data_manager.py, 83, INFO, Saving data for CPT
# 2025-01-31 13:57:34,516, data_manager.py, 83, INFO, Saving data for CRL
# 2025-01-31 13:57:35,195, data_manager.py, 83, INFO, Saving data for CRM
# 2025-01-31 13:57:35,799, data_manager.py, 83, INFO, Saving data for CSCO
# 2025-01-31 13:57:36,424, data_manager.py, 83, INFO, Saving data for CSGP
# 2025-01-31 13:57:37,054, data_manager.py, 83, INFO, Saving data for CSX
# 2025-01-31 13:57:37,632, data_manager.py, 83, INFO, Saving data for CTAS
# 2025-01-31 13:57:38,198, data_manager.py, 83, INFO, Saving data for CTLT
# 2025-01-31 13:57:38,762, data_manager.py, 83, INFO, Saving data for CTRA
# 2025-01-31 13:57:39,325, data_manager.py, 83, INFO, Saving data for CTSH
# 2025-01-31 13:57:39,923, data_manager.py, 83, INFO, Saving data for CTVA
# 2025-01-31 13:57:40,486, data_manager.py, 83, INFO, Saving data for CVS
# 2025-01-31 13:57:41,188, data_manager.py, 83, INFO, Saving data for CVX
# 2025-01-31 13:57:41,850, data_manager.py, 83, INFO, Saving data for CZR
# 2025-01-31 13:57:42,453, data_manager.py, 83, INFO, Saving data for D
# 2025-01-31 13:57:43,022, data_manager.py, 83, INFO, Saving data for DAL
# 2025-01-31 13:57:43,587, data_manager.py, 83, INFO, Saving data for DAY
# 2025-01-31 13:57:44,158, data_manager.py, 83, INFO, Saving data for DD
# 2025-01-31 13:57:44,744, data_manager.py, 83, INFO, Saving data for DE
# 2025-01-31 13:57:45,383, data_manager.py, 83, INFO, Saving data for DFS
# 2025-01-31 13:57:46,046, data_manager.py, 83, INFO, Saving data for DG
# 2025-01-31 13:57:46,696, data_manager.py, 83, INFO, Saving data for DGX
# 2025-01-31 13:57:47,289, data_manager.py, 83, INFO, Saving data for DHI
# 2025-01-31 13:57:47,859, data_manager.py, 83, INFO, Saving data for DHR
# 2025-01-31 13:57:48,449, data_manager.py, 83, INFO, Saving data for DIS
# 2025-01-31 13:57:49,048, data_manager.py, 83, INFO, Saving data for DLR
# 2025-01-31 13:57:49,671, data_manager.py, 83, INFO, Saving data for DLTR
# 2025-01-31 13:57:50,250, data_manager.py, 83, INFO, Saving data for DOV
# 2025-01-31 13:57:50,819, data_manager.py, 83, INFO, Saving data for DOW
# 2025-01-31 13:57:51,388, data_manager.py, 83, INFO, Saving data for DPZ
# 2025-01-31 13:57:51,965, data_manager.py, 83, INFO, Saving data for DRI
# 2025-01-31 13:57:52,592, data_manager.py, 83, INFO, Saving data for DTE
# 2025-01-31 13:57:53,191, data_manager.py, 83, INFO, Saving data for DUK
# 2025-01-31 13:57:53,758, data_manager.py, 83, INFO, Saving data for DVA
# 2025-01-31 13:57:54,315, data_manager.py, 83, INFO, Saving data for DVN
# 2025-01-31 13:57:54,875, data_manager.py, 83, INFO, Saving data for DXCM
# 2025-01-31 13:57:55,437, data_manager.py, 83, INFO, Saving data for EA
# 2025-01-31 13:57:56,022, data_manager.py, 83, INFO, Saving data for EBAY
# 2025-01-31 13:57:56,576, data_manager.py, 83, INFO, Saving data for ECL
# 2025-01-31 13:57:57,203, data_manager.py, 83, INFO, Saving data for ED
# 2025-01-31 13:57:57,805, data_manager.py, 83, INFO, Saving data for EFX
# 2025-01-31 13:57:58,457, data_manager.py, 83, INFO, Saving data for EG
# 2025-01-31 13:57:59,030, data_manager.py, 83, INFO, Saving data for EIX
# 2025-01-31 13:57:59,591, data_manager.py, 83, INFO, Saving data for EL
# 2025-01-31 13:58:00,187, data_manager.py, 83, INFO, Saving data for ELV
# 2025-01-31 13:58:00,783, data_manager.py, 83, INFO, Saving data for EMN
# 2025-01-31 13:58:01,384, data_manager.py, 83, INFO, Saving data for EMR
# 2025-01-31 13:58:01,987, data_manager.py, 83, INFO, Saving data for ENPH
# 2025-01-31 13:58:02,595, data_manager.py, 83, INFO, Saving data for EOG
# 2025-01-31 13:58:03,163, data_manager.py, 83, INFO, Saving data for EPAM
# 2025-01-31 13:58:03,806, data_manager.py, 83, INFO, Saving data for EQIX
# 2025-01-31 13:58:04,399, data_manager.py, 83, INFO, Saving data for EQR
# 2025-01-31 13:58:04,988, data_manager.py, 83, INFO, Saving data for EQT
# 2025-01-31 13:58:05,564, data_manager.py, 83, INFO, Saving data for ES
# 2025-01-31 13:58:06,209, data_manager.py, 83, INFO, Saving data for ESS
# 2025-01-31 13:58:07,282, data_manager.py, 83, INFO, Saving data for ETN
# 2025-01-31 13:58:07,883, data_manager.py, 83, INFO, Saving data for ETR
# 2025-01-31 13:58:08,532, data_manager.py, 83, INFO, Saving data for ETSY
# 2025-01-31 13:58:09,143, data_manager.py, 83, INFO, Saving data for EVRG
# 2025-01-31 13:58:09,922, data_manager.py, 83, INFO, Saving data for EW
# 2025-01-31 13:58:10,535, data_manager.py, 83, INFO, Saving data for EXC
# 2025-01-31 13:58:11,127, data_manager.py, 83, INFO, Saving data for EXPD
# 2025-01-31 13:58:11,804, data_manager.py, 83, INFO, Saving data for EXPE
# 2025-01-31 13:58:12,535, data_manager.py, 83, INFO, Saving data for EXR
# 2025-01-31 13:58:13,399, data_manager.py, 83, INFO, Saving data for F
# 2025-01-31 13:58:14,077, data_manager.py, 83, INFO, Saving data for FANG
# 2025-01-31 13:58:14,857, data_manager.py, 83, INFO, Saving data for FAST
# 2025-01-31 13:58:15,488, data_manager.py, 83, INFO, Saving data for FCX
# 2025-01-31 13:58:16,219, data_manager.py, 83, INFO, Saving data for FDS
# 2025-01-31 13:58:17,047, data_manager.py, 83, INFO, Saving data for FDX
# 2025-01-31 13:58:17,704, data_manager.py, 83, INFO, Saving data for FE
# 2025-01-31 13:58:18,333, data_manager.py, 83, INFO, Saving data for FFIV
# 2025-01-31 13:58:18,977, data_manager.py, 83, INFO, Saving data for FI
# 2025-01-31 13:58:19,642, data_manager.py, 83, INFO, Saving data for FICO
# 2025-01-31 13:58:20,235, data_manager.py, 83, INFO, Saving data for FIS
# 2025-01-31 13:58:21,201, data_manager.py, 83, INFO, Saving data for FITB
# 2025-01-31 13:58:21,794, data_manager.py, 83, INFO, Saving data for FLT
# 2025-01-31 13:58:22,362, data_manager.py, 83, INFO, Saving data for FMC
# 2025-01-31 13:58:23,021, data_manager.py, 83, INFO, Saving data for FOX
# 2025-01-31 13:58:23,651, data_manager.py, 83, INFO, Saving data for FOXA
# 2025-01-31 13:58:24,214, data_manager.py, 83, INFO, Saving data for FRT
# 2025-01-31 13:58:24,780, data_manager.py, 83, INFO, Saving data for FSLR
# 2025-01-31 13:58:25,368, data_manager.py, 83, INFO, Saving data for FTNT
# 2025-01-31 13:58:25,961, data_manager.py, 83, INFO, Saving data for FTV
# 2025-01-31 13:58:26,528, data_manager.py, 83, INFO, Saving data for GD
# 2025-01-31 13:58:27,089, data_manager.py, 83, INFO, Saving data for GE
# 2025-01-31 13:58:27,657, data_manager.py, 83, INFO, Saving data for GEHC
# 2025-01-31 13:58:28,303, data_manager.py, 83, INFO, Saving data for GEN
# 2025-01-31 13:58:28,895, data_manager.py, 83, INFO, Saving data for GILD
# 2025-01-31 13:58:29,459, data_manager.py, 83, INFO, Saving data for GIS
# 2025-01-31 13:58:30,026, data_manager.py, 83, INFO, Saving data for GL
# 2025-01-31 13:58:30,590, data_manager.py, 83, INFO, Saving data for GLW
# 2025-01-31 13:58:31,175, data_manager.py, 83, INFO, Saving data for GM
# 2025-01-31 13:58:31,739, data_manager.py, 83, INFO, Saving data for GNRC
# 2025-01-31 13:58:32,334, data_manager.py, 83, INFO, Saving data for GOOG
# 2025-01-31 13:58:32,919, data_manager.py, 83, INFO, Saving data for GOOGL
# 2025-01-31 13:58:33,477, data_manager.py, 83, INFO, Saving data for GPC
# 2025-01-31 13:58:34,123, data_manager.py, 83, INFO, Saving data for GPN
# 2025-01-31 13:58:34,693, data_manager.py, 83, INFO, Saving data for GRMN
# 2025-01-31 13:58:35,424, data_manager.py, 83, INFO, Saving data for GS
# 2025-01-31 13:58:36,029, data_manager.py, 83, INFO, Saving data for GWW
# 2025-01-31 13:58:36,681, data_manager.py, 83, INFO, Saving data for HAL
# 2025-01-31 13:58:37,265, data_manager.py, 83, INFO, Saving data for HAS
# 2025-01-31 13:58:37,839, data_manager.py, 83, INFO, Saving data for HBAN
# 2025-01-31 13:58:38,401, data_manager.py, 83, INFO, Saving data for HCA
# 2025-01-31 13:58:38,981, data_manager.py, 83, INFO, Saving data for HD
# 2025-01-31 13:58:39,604, data_manager.py, 83, INFO, Saving data for HES
# 2025-01-31 13:58:40,180, data_manager.py, 83, INFO, Saving data for HIG
# 2025-01-31 13:58:40,817, data_manager.py, 83, INFO, Saving data for HII
# 2025-01-31 13:58:41,386, data_manager.py, 83, INFO, Saving data for HLT
# 2025-01-31 13:58:41,964, data_manager.py, 83, INFO, Saving data for HOLX
# 2025-01-31 13:58:42,629, data_manager.py, 83, INFO, Saving data for HON
# 2025-01-31 13:58:43,203, data_manager.py, 83, INFO, Saving data for HPE
# 2025-01-31 13:58:43,809, data_manager.py, 83, INFO, Saving data for HPQ
# 2025-01-31 13:58:44,404, data_manager.py, 83, INFO, Saving data for HRL
# 2025-01-31 13:58:45,071, data_manager.py, 83, INFO, Saving data for HSIC
# 2025-01-31 13:58:45,640, data_manager.py, 83, INFO, Saving data for HST
# 2025-01-31 13:58:46,206, data_manager.py, 83, INFO, Saving data for HSY
# 2025-01-31 13:58:46,793, data_manager.py, 83, INFO, Saving data for HUBB
# 2025-01-31 13:58:47,394, data_manager.py, 83, INFO, Saving data for HUM
# 2025-01-31 13:58:47,959, data_manager.py, 83, INFO, Saving data for HWM
# 2025-01-31 13:58:48,553, data_manager.py, 83, INFO, Saving data for IBM
# 2025-01-31 13:58:49,225, data_manager.py, 83, INFO, Saving data for ICE
# 2025-01-31 13:58:49,792, data_manager.py, 83, INFO, Saving data for IDXX
# 2025-01-31 13:58:50,358, data_manager.py, 83, INFO, Saving data for IEX
# 2025-01-31 13:58:51,022, data_manager.py, 83, INFO, Saving data for IFF
# 2025-01-31 13:58:51,593, data_manager.py, 83, INFO, Saving data for ILMN
# 2025-01-31 13:58:52,233, data_manager.py, 83, INFO, Saving data for INCY
# 2025-01-31 13:58:52,863, data_manager.py, 83, INFO, Saving data for INTC
# 2025-01-31 13:58:53,463, data_manager.py, 83, INFO, Saving data for INTU
# 2025-01-31 13:58:54,084, data_manager.py, 83, INFO, Saving data for INVH
# 2025-01-31 13:58:54,655, data_manager.py, 83, INFO, Saving data for IP
# 2025-01-31 13:58:55,222, data_manager.py, 83, INFO, Saving data for IPG
# 2025-01-31 13:58:55,803, data_manager.py, 83, INFO, Saving data for IQV
# 2025-01-31 13:58:56,431, data_manager.py, 83, INFO, Saving data for IR
# 2025-01-31 13:58:57,081, data_manager.py, 83, INFO, Saving data for IRM
# 2025-01-31 13:58:57,658, data_manager.py, 83, INFO, Saving data for ISRG
# 2025-01-31 13:58:58,231, data_manager.py, 83, INFO, Saving data for IT
# 2025-01-31 13:58:58,841, data_manager.py, 83, INFO, Saving data for ITW
# 2025-01-31 13:58:59,414, data_manager.py, 83, INFO, Saving data for IVZ
# 2025-01-31 13:58:59,981, data_manager.py, 83, INFO, Saving data for J
# 2025-01-31 13:59:00,546, data_manager.py, 83, INFO, Saving data for JBHT
# 2025-01-31 13:59:01,126, data_manager.py, 83, INFO, Saving data for JBL
# 2025-01-31 13:59:01,757, data_manager.py, 83, INFO, Saving data for JCI
# 2025-01-31 13:59:02,386, data_manager.py, 83, INFO, Saving data for JKHY
# 2025-01-31 13:59:02,986, data_manager.py, 83, INFO, Saving data for JNJ
# 2025-01-31 13:59:03,559, data_manager.py, 83, INFO, Saving data for JNPR
# 2025-01-31 13:59:04,144, data_manager.py, 83, INFO, Saving data for JPM
# 2025-01-31 13:59:04,727, data_manager.py, 83, INFO, Saving data for K
# 2025-01-31 13:59:05,308, data_manager.py, 83, INFO, Saving data for KDP
# 2025-01-31 13:59:05,889, data_manager.py, 83, INFO, Saving data for KEY
# 2025-01-31 13:59:06,520, data_manager.py, 83, INFO, Saving data for KEYS
# 2025-01-31 13:59:07,797, data_manager.py, 83, INFO, Saving data for KHC
# 2025-01-31 13:59:08,454, data_manager.py, 83, INFO, Saving data for KIM
# 2025-01-31 13:59:09,081, data_manager.py, 83, INFO, Saving data for KLAC
# 2025-01-31 13:59:09,678, data_manager.py, 83, INFO, Saving data for KMB
# 2025-01-31 13:59:10,279, data_manager.py, 83, INFO, Saving data for KMI
# 2025-01-31 13:59:10,857, data_manager.py, 83, INFO, Saving data for KMX
# 2025-01-31 13:59:11,493, data_manager.py, 83, INFO, Saving data for KO
# 2025-01-31 13:59:12,065, data_manager.py, 83, INFO, Saving data for KR
# 2025-01-31 13:59:12,792, data_manager.py, 83, INFO, Saving data for KVUE
# 2025-01-31 13:59:13,437, data_manager.py, 83, INFO, Saving data for L
# 2025-01-31 13:59:14,373, data_manager.py, 83, INFO, Saving data for LDOS
# 2025-01-31 13:59:15,361, data_manager.py, 83, INFO, Saving data for LEN
# 2025-01-31 13:59:16,006, data_manager.py, 83, INFO, Saving data for LH
# 2025-01-31 13:59:16,660, data_manager.py, 83, INFO, Saving data for LHX
# 2025-01-31 13:59:17,238, data_manager.py, 83, INFO, Saving data for LIN
# 2025-01-31 13:59:17,811, data_manager.py, 83, INFO, Saving data for LKQ
# 2025-01-31 13:59:18,386, data_manager.py, 83, INFO, Saving data for LLY
# 2025-01-31 13:59:18,970, data_manager.py, 83, INFO, Saving data for LMT
# 2025-01-31 13:59:19,536, data_manager.py, 83, INFO, Saving data for LNT
# 2025-01-31 13:59:20,143, data_manager.py, 83, INFO, Saving data for LOW
# 2025-01-31 13:59:20,843, data_manager.py, 83, INFO, Saving data for LRCX
# 2025-01-31 13:59:21,432, data_manager.py, 83, INFO, Saving data for LULU
# 2025-01-31 13:59:22,007, data_manager.py, 83, INFO, Saving data for LUV
# 2025-01-31 13:59:22,585, data_manager.py, 83, INFO, Saving data for LVS
# 2025-01-31 13:59:23,151, data_manager.py, 83, INFO, Saving data for LW
# 2025-01-31 13:59:23,721, data_manager.py, 83, INFO, Saving data for LYB
# 2025-01-31 13:59:24,288, data_manager.py, 83, INFO, Saving data for LYV
# 2025-01-31 13:59:24,854, data_manager.py, 83, INFO, Saving data for MA
# 2025-01-31 13:59:25,474, data_manager.py, 83, INFO, Saving data for MAA
# 2025-01-31 13:59:26,086, data_manager.py, 83, INFO, Saving data for MAR
# 2025-01-31 13:59:26,659, data_manager.py, 83, INFO, Saving data for MAS
# 2025-01-31 13:59:27,232, data_manager.py, 83, INFO, Saving data for MCD
# 2025-01-31 13:59:27,801, data_manager.py, 83, INFO, Saving data for MCHP
# 2025-01-31 13:59:28,385, data_manager.py, 83, INFO, Saving data for MCK
# 2025-01-31 13:59:28,953, data_manager.py, 83, INFO, Saving data for MCO
# 2025-01-31 13:59:29,549, data_manager.py, 83, INFO, Saving data for MDLZ
# 2025-01-31 13:59:30,116, data_manager.py, 83, INFO, Saving data for MDT
# 2025-01-31 13:59:30,687, data_manager.py, 83, INFO, Saving data for MET
# 2025-01-31 13:59:31,253, data_manager.py, 83, INFO, Saving data for META
# 2025-01-31 13:59:31,902, data_manager.py, 83, INFO, Saving data for MGM
# 2025-01-31 13:59:32,468, data_manager.py, 83, INFO, Saving data for MHK
# 2025-01-31 13:59:33,042, data_manager.py, 83, INFO, Saving data for MKC
# 2025-01-31 13:59:33,661, data_manager.py, 83, INFO, Saving data for MKTX
# 2025-01-31 13:59:34,230, data_manager.py, 83, INFO, Saving data for MLM
# 2025-01-31 13:59:34,805, data_manager.py, 83, INFO, Saving data for MMC
# 2025-01-31 13:59:35,375, data_manager.py, 83, INFO, Saving data for MMM
# 2025-01-31 13:59:35,948, data_manager.py, 83, INFO, Saving data for MNST
# 2025-01-31 13:59:36,539, data_manager.py, 83, INFO, Saving data for MO
# 2025-01-31 13:59:37,173, data_manager.py, 83, INFO, Saving data for MOH
# 2025-01-31 13:59:37,784, data_manager.py, 83, INFO, Saving data for MOS
# 2025-01-31 13:59:38,354, data_manager.py, 83, INFO, Saving data for MPC
# 2025-01-31 13:59:38,925, data_manager.py, 83, INFO, Saving data for MPWR
# 2025-01-31 13:59:39,511, data_manager.py, 83, INFO, Saving data for MRK
# 2025-01-31 13:59:40,111, data_manager.py, 83, INFO, Saving data for MRNA
# 2025-01-31 13:59:40,677, data_manager.py, 83, INFO, Saving data for MRO
# 2025-01-31 13:59:41,253, data_manager.py, 83, INFO, Saving data for MS
# 2025-01-31 13:59:41,925, data_manager.py, 83, INFO, Saving data for MSCI
# 2025-01-31 13:59:42,806, data_manager.py, 83, INFO, Saving data for MSFT
# 2025-01-31 13:59:43,430, data_manager.py, 83, INFO, Saving data for MSI
# 2025-01-31 13:59:44,083, data_manager.py, 83, INFO, Saving data for MTB
# 2025-01-31 13:59:44,697, data_manager.py, 83, INFO, Saving data for MTCH
# 2025-01-31 13:59:45,398, data_manager.py, 83, INFO, Saving data for MTD
# 2025-01-31 13:59:46,002, data_manager.py, 83, INFO, Saving data for MU
# 2025-01-31 13:59:46,641, data_manager.py, 83, INFO, Saving data for NCLH
# 2025-01-31 13:59:47,281, data_manager.py, 83, INFO, Saving data for NDAQ
# 2025-01-31 13:59:47,860, data_manager.py, 83, INFO, Saving data for NDSN
# 2025-01-31 13:59:48,445, data_manager.py, 83, INFO, Saving data for NEE
# 2025-01-31 13:59:49,107, data_manager.py, 83, INFO, Saving data for NEM
# 2025-01-31 13:59:49,757, data_manager.py, 83, INFO, Saving data for NFLX
# 2025-01-31 13:59:50,324, data_manager.py, 83, INFO, Saving data for NI
# 2025-01-31 13:59:50,908, data_manager.py, 83, INFO, Saving data for NKE
# 2025-01-31 13:59:51,493, data_manager.py, 83, INFO, Saving data for NOC
# 2025-01-31 13:59:52,059, data_manager.py, 83, INFO, Saving data for NOW
# 2025-01-31 13:59:52,656, data_manager.py, 83, INFO, Saving data for NRG
# 2025-01-31 13:59:53,228, data_manager.py, 83, INFO, Saving data for NSC
# 2025-01-31 13:59:53,798, data_manager.py, 83, INFO, Saving data for NTAP
# 2025-01-31 13:59:54,495, data_manager.py, 83, INFO, Saving data for NTRS
# 2025-01-31 13:59:55,092, data_manager.py, 83, INFO, Saving data for NUE
# 2025-01-31 13:59:55,700, data_manager.py, 83, INFO, Saving data for NVDA
# 2025-01-31 13:59:56,293, data_manager.py, 83, INFO, Saving data for NVR
# 2025-01-31 13:59:57,124, data_manager.py, 83, INFO, Saving data for NWS
# 2025-01-31 13:59:57,900, data_manager.py, 83, INFO, Saving data for NWSA
# 2025-01-31 13:59:58,527, data_manager.py, 83, INFO, Saving data for NXPI
# 2025-01-31 13:59:59,182, data_manager.py, 83, INFO, Saving data for O
# 2025-01-31 13:59:59,817, data_manager.py, 83, INFO, Saving data for ODFL
# 2025-01-31 14:00:00,384, data_manager.py, 83, INFO, Saving data for OKE
# 2025-01-31 14:00:01,024, data_manager.py, 83, INFO, Saving data for OMC
# 2025-01-31 14:00:01,595, data_manager.py, 83, INFO, Saving data for ON
# 2025-01-31 14:00:02,177, data_manager.py, 83, INFO, Saving data for ORCL
# 2025-01-31 14:00:02,777, data_manager.py, 83, INFO, Saving data for ORLY
# 2025-01-31 14:00:03,340, data_manager.py, 83, INFO, Saving data for OTIS
# 2025-01-31 14:00:03,950, data_manager.py, 83, INFO, Saving data for OXY
# 2025-01-31 14:00:04,511, data_manager.py, 83, INFO, Saving data for PANW
# 2025-01-31 14:00:05,113, data_manager.py, 83, INFO, Saving data for PARA
# 2025-01-31 14:00:05,670, data_manager.py, 83, INFO, Saving data for PAYC
# 2025-01-31 14:00:06,275, data_manager.py, 83, INFO, Saving data for PAYX
# 2025-01-31 14:00:07,191, data_manager.py, 83, INFO, Saving data for PCAR
# 2025-01-31 14:00:07,786, data_manager.py, 83, INFO, Saving data for PCG
# 2025-01-31 14:00:08,393, data_manager.py, 83, INFO, Saving data for PEAK
# 2025-01-31 14:00:09,198, data_manager.py, 83, INFO, Saving data for PEG
# 2025-01-31 14:00:10,206, data_manager.py, 83, INFO, Saving data for PEP
# 2025-01-31 14:00:12,400, data_manager.py, 83, INFO, Saving data for PFE
# 2025-01-31 14:00:13,253, data_manager.py, 83, INFO, Saving data for PFG
# 2025-01-31 14:00:14,237, data_manager.py, 83, INFO, Saving data for PG
# 2025-01-31 14:00:15,893, data_manager.py, 83, INFO, Saving data for PGR
# 2025-01-31 14:00:16,644, data_manager.py, 83, INFO, Saving data for PH
# 2025-01-31 14:00:17,358, data_manager.py, 83, INFO, Saving data for PHM
# 2025-01-31 14:00:18,083, data_manager.py, 83, INFO, Saving data for PKG
# 2025-01-31 14:00:18,834, data_manager.py, 83, INFO, Saving data for PLD
# 2025-01-31 14:00:19,573, data_manager.py, 83, INFO, Saving data for PM
# 2025-01-31 14:00:20,493, data_manager.py, 83, INFO, Saving data for PNC
# 2025-01-31 14:00:21,335, data_manager.py, 83, INFO, Saving data for PNR
# 2025-01-31 14:00:22,041, data_manager.py, 83, INFO, Saving data for PNW
# 2025-01-31 14:00:22,755, data_manager.py, 83, INFO, Saving data for PODD
# 2025-01-31 14:00:23,526, data_manager.py, 83, INFO, Saving data for POOL
# 2025-01-31 14:00:24,204, data_manager.py, 83, INFO, Saving data for PPG
# 2025-01-31 14:00:24,897, data_manager.py, 83, INFO, Saving data for PPL
# 2025-01-31 14:00:25,701, data_manager.py, 83, INFO, Saving data for PRU
# 2025-01-31 14:00:26,425, data_manager.py, 83, INFO, Saving data for PSA
# 2025-01-31 14:00:27,188, data_manager.py, 83, INFO, Saving data for PSX
# 2025-01-31 14:00:28,009, data_manager.py, 83, INFO, Saving data for PTC
# 2025-01-31 14:00:28,799, data_manager.py, 83, INFO, Saving data for PWR
# 2025-01-31 14:00:29,481, data_manager.py, 83, INFO, Saving data for PXD
# 2025-01-31 14:00:30,283, data_manager.py, 83, INFO, Saving data for PYPL
# 2025-01-31 14:00:31,110, data_manager.py, 83, INFO, Saving data for QCOM
# 2025-01-31 14:00:31,852, data_manager.py, 83, INFO, Saving data for QRVO
# 2025-01-31 14:00:32,707, data_manager.py, 83, INFO, Saving data for RCL
# 2025-01-31 14:00:33,412, data_manager.py, 83, INFO, Saving data for REG
# 2025-01-31 14:00:34,109, data_manager.py, 83, INFO, Saving data for REGN
# 2025-01-31 14:00:34,824, data_manager.py, 83, INFO, Saving data for RF
# 2025-01-31 14:00:35,795, data_manager.py, 83, INFO, Saving data for RHI
# 2025-01-31 14:00:37,005, data_manager.py, 83, INFO, Saving data for RJF
# 2025-01-31 14:00:38,194, data_manager.py, 83, INFO, Saving data for RL
# 2025-01-31 14:00:39,598, data_manager.py, 83, INFO, Saving data for RMD
# 2025-01-31 14:00:40,439, data_manager.py, 83, INFO, Saving data for ROK
# 2025-01-31 14:00:41,162, data_manager.py, 83, INFO, Saving data for ROL
# 2025-01-31 14:00:41,868, data_manager.py, 83, INFO, Saving data for ROP
# 2025-01-31 14:00:42,714, data_manager.py, 83, INFO, Saving data for ROST
# 2025-01-31 14:00:43,394, data_manager.py, 83, INFO, Saving data for RSG
# 2025-01-31 14:00:44,213, data_manager.py, 83, INFO, Saving data for RTX
# 2025-01-31 14:00:45,001, data_manager.py, 83, INFO, Saving data for RVTY
# 2025-01-31 14:00:45,610, data_manager.py, 83, INFO, Saving data for SBAC
# 2025-01-31 14:00:46,273, data_manager.py, 83, INFO, Saving data for SBUX
# 2025-01-31 14:00:46,875, data_manager.py, 83, INFO, Saving data for SCHW
# 2025-01-31 14:00:47,589, data_manager.py, 83, INFO, Saving data for SHW
# 2025-01-31 14:00:48,207, data_manager.py, 83, INFO, Saving data for SJM
# 2025-01-31 14:00:48,850, data_manager.py, 83, INFO, Saving data for SLB
# 2025-01-31 14:00:49,530, data_manager.py, 83, INFO, Saving data for SNA
# 2025-01-31 14:00:50,162, data_manager.py, 83, INFO, Saving data for SNPS
# 2025-01-31 14:00:50,793, data_manager.py, 83, INFO, Saving data for SO
# 2025-01-31 14:00:51,401, data_manager.py, 83, INFO, Saving data for SPG
# 2025-01-31 14:00:52,091, data_manager.py, 83, INFO, Saving data for SPGI
# 2025-01-31 14:00:52,693, data_manager.py, 83, INFO, Saving data for SRE
# 2025-01-31 14:00:53,304, data_manager.py, 83, INFO, Saving data for STE
# 2025-01-31 14:00:54,364, data_manager.py, 83, INFO, Saving data for STLD
# 2025-01-31 14:00:55,336, data_manager.py, 83, INFO, Saving data for STT
# 2025-01-31 14:00:56,501, data_manager.py, 83, INFO, Saving data for STX
# 2025-01-31 14:00:57,226, data_manager.py, 83, INFO, Saving data for STZ
# 2025-01-31 14:00:57,886, data_manager.py, 83, INFO, Saving data for SWK
# 2025-01-31 14:00:58,602, data_manager.py, 83, INFO, Saving data for SWKS
# 2025-01-31 14:00:59,268, data_manager.py, 83, INFO, Saving data for SYF
# 2025-01-31 14:00:59,955, data_manager.py, 83, INFO, Saving data for SYK
# 2025-01-31 14:01:00,637, data_manager.py, 83, INFO, Saving data for SYY
# 2025-01-31 14:01:01,242, data_manager.py, 83, INFO, Saving data for T
# 2025-01-31 14:01:01,827, data_manager.py, 83, INFO, Saving data for TAP
# 2025-01-31 14:01:02,471, data_manager.py, 83, INFO, Saving data for TDG
# 2025-01-31 14:01:03,105, data_manager.py, 83, INFO, Saving data for TDY
# 2025-01-31 14:01:03,722, data_manager.py, 83, INFO, Saving data for TECH
# 2025-01-31 14:01:04,321, data_manager.py, 83, INFO, Saving data for TEL
# 2025-01-31 14:01:04,945, data_manager.py, 83, INFO, Saving data for TER
# 2025-01-31 14:01:05,633, data_manager.py, 83, INFO, Saving data for TFC
# 2025-01-31 14:01:06,215, data_manager.py, 83, INFO, Saving data for TFX
# 2025-01-31 14:01:07,386, data_manager.py, 83, INFO, Saving data for TGT
# 2025-01-31 14:01:08,060, data_manager.py, 83, INFO, Saving data for TJX
# 2025-01-31 14:01:08,662, data_manager.py, 83, INFO, Saving data for TMO
# 2025-01-31 14:01:09,238, data_manager.py, 83, INFO, Saving data for TMUS
# 2025-01-31 14:01:09,891, data_manager.py, 83, INFO, Saving data for TPR
# 2025-01-31 14:01:10,505, data_manager.py, 83, INFO, Saving data for TRGP
# 2025-01-31 14:01:11,111, data_manager.py, 83, INFO, Saving data for TRMB
# 2025-01-31 14:01:11,876, data_manager.py, 83, INFO, Saving data for TROW
# 2025-01-31 14:01:12,449, data_manager.py, 83, INFO, Saving data for TRV
# 2025-01-31 14:01:13,062, data_manager.py, 83, INFO, Saving data for TSCO
# 2025-01-31 14:01:13,648, data_manager.py, 83, INFO, Saving data for TSLA
# 2025-01-31 14:01:14,251, data_manager.py, 83, INFO, Saving data for TSN
# 2025-01-31 14:01:14,861, data_manager.py, 83, INFO, Saving data for TT
# 2025-01-31 14:01:15,445, data_manager.py, 83, INFO, Saving data for TTWO
# 2025-01-31 14:01:16,151, data_manager.py, 83, INFO, Saving data for TXN
# 2025-01-31 14:01:16,872, data_manager.py, 83, INFO, Saving data for TXT
# 2025-01-31 14:01:17,449, data_manager.py, 83, INFO, Saving data for TYL
# 2025-01-31 14:01:18,115, data_manager.py, 83, INFO, Saving data for UAL
# 2025-01-31 14:01:18,701, data_manager.py, 83, INFO, Saving data for UBER
# 2025-01-31 14:01:19,267, data_manager.py, 83, INFO, Saving data for UDR
# 2025-01-31 14:01:19,867, data_manager.py, 83, INFO, Saving data for UHS
# 2025-01-31 14:01:20,479, data_manager.py, 83, INFO, Saving data for ULTA
# 2025-01-31 14:01:21,115, data_manager.py, 83, INFO, Saving data for UNH
# 2025-01-31 14:01:21,790, data_manager.py, 83, INFO, Saving data for UNP
# 2025-01-31 14:01:22,369, data_manager.py, 83, INFO, Saving data for UPS
# 2025-01-31 14:01:22,952, data_manager.py, 83, INFO, Saving data for URI
# 2025-01-31 14:01:23,602, data_manager.py, 83, INFO, Saving data for USB
# 2025-01-31 14:01:24,195, data_manager.py, 83, INFO, Saving data for V
# 2025-01-31 14:01:24,924, data_manager.py, 83, INFO, Saving data for VFC
# 2025-01-31 14:01:25,558, data_manager.py, 83, INFO, Saving data for VICI
# 2025-01-31 14:01:26,228, data_manager.py, 83, INFO, Saving data for VLO
# 2025-01-31 14:01:26,833, data_manager.py, 83, INFO, Saving data for VLTO
# 2025-01-31 14:01:27,400, data_manager.py, 83, INFO, Saving data for VMC
# 2025-01-31 14:01:27,991, data_manager.py, 83, INFO, Saving data for VRSK
# 2025-01-31 14:01:28,559, data_manager.py, 83, INFO, Saving data for VRSN
# 2025-01-31 14:01:29,150, data_manager.py, 83, INFO, Saving data for VRTX
# 2025-01-31 14:01:29,840, data_manager.py, 83, INFO, Saving data for VTR
# 2025-01-31 14:01:30,437, data_manager.py, 83, INFO, Saving data for VTRS
# 2025-01-31 14:01:31,158, data_manager.py, 83, INFO, Saving data for VZ
# 2025-01-31 14:01:31,755, data_manager.py, 83, INFO, Saving data for WAB
# 2025-01-31 14:01:32,350, data_manager.py, 83, INFO, Saving data for WAT
# 2025-01-31 14:01:32,941, data_manager.py, 83, INFO, Saving data for WBA
# 2025-01-31 14:01:33,521, data_manager.py, 83, INFO, Saving data for WBD
# 2025-01-31 14:01:34,105, data_manager.py, 83, INFO, Saving data for WDC
# 2025-01-31 14:01:34,723, data_manager.py, 83, INFO, Saving data for WEC
# 2025-01-31 14:01:35,374, data_manager.py, 83, INFO, Saving data for WELL
# 2025-01-31 14:01:36,019, data_manager.py, 83, INFO, Saving data for WFC
# 2025-01-31 14:01:36,597, data_manager.py, 83, INFO, Saving data for WHR
# 2025-01-31 14:01:37,218, data_manager.py, 83, INFO, Saving data for WM
# 2025-01-31 14:01:37,800, data_manager.py, 83, INFO, Saving data for WMB
# 2025-01-31 14:01:38,404, data_manager.py, 83, INFO, Saving data for WMT
# 2025-01-31 14:01:39,023, data_manager.py, 83, INFO, Saving data for WRB
# 2025-01-31 14:01:39,702, data_manager.py, 83, INFO, Saving data for WRK
# 2025-01-31 14:01:40,291, data_manager.py, 83, INFO, Saving data for WST
# 2025-01-31 14:01:40,944, data_manager.py, 83, INFO, Saving data for WTW
# 2025-01-31 14:01:41,532, data_manager.py, 83, INFO, Saving data for WY
# 2025-01-31 14:01:42,128, data_manager.py, 83, INFO, Saving data for WYNN
# 2025-01-31 14:01:42,728, data_manager.py, 83, INFO, Saving data for XEL
# 2025-01-31 14:01:43,305, data_manager.py, 83, INFO, Saving data for XOM
# 2025-01-31 14:01:43,898, data_manager.py, 83, INFO, Saving data for XRAY
# 2025-01-31 14:01:44,551, data_manager.py, 83, INFO, Saving data for XYL
# 2025-01-31 14:01:45,131, data_manager.py, 83, INFO, Saving data for YUM
# 2025-01-31 14:01:45,712, data_manager.py, 83, INFO, Saving data for ZBH
# 2025-01-31 14:01:46,290, data_manager.py, 83, INFO, Saving data for ZBRA
# 2025-01-31 14:01:46,983, data_manager.py, 83, INFO, Saving data for ZION
# 2025-01-31 14:01:47,575, data_manager.py, 83, INFO, Saving data for ZTS

# %% [markdown]
# Finally, add features to the data set and save to a *feature store*.

# %%
dm.featurize()
# Out:
# 2025-01-31 14:01:48,222, data_manager.py, 114, INFO, Creating features data.
# 2025-01-31 14:01:48,224, data_manager.py, 124, INFO, Loading price data from ../../05_src/data/prices/
# /opt/miniconda3/envs/dsi_participant/lib/python3.9/site-packages/dask/dataframe/core.py:5310: UserWarning: New index has same name as existing, this is a no-op.
#   warnings.warn(
# 2025-01-31 14:01:49,794, data_manager.py, 133, INFO, Creating features
# /Users/kate/Desktop/DSI UofT/production/production/01_materials/labs/../../05_src/data_manager.py:136: UserWarning: `meta` is not specified, inferred from partial data. Please provide `meta` if the result is unexpected.
#   Before: .apply(func)
#   After:  .apply(func, meta={'x': 'f8', 'y': 'f8'}) for dataframe result
#   or:     .apply(func, meta=('x', 'f8'))            for series result
#   features = (price_dd.groupby('Ticker', group_keys=False)
# 2025-01-31 14:01:49,822, data_manager.py, 158, INFO, Saving features to ../../05_src/data/features/stock_features.parquet
